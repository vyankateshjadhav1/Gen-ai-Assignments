# %%
# !pip install transformers
# !pip install torch
# !pip install sentencepiece

# %%
from transformers import pipeline

# %%
from transformers import pipeline

generator = pipeline(
    task="text-generation",
    model="google/flan-t5-base"
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ...

# %%
def ask_model(prompt):
    output = generator(prompt, max_length=200)
    return output[0]['generated_text']

# %%
zero_shot_prompt = """
Classify sentiment as Positive, Negative or Neutral:

Sentence: I love this AI course.
"""

print("Zero Shot Result:")
print(ask_model(zero_shot_prompt))
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Zero Shot Result:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Classify sentiment as Positive, Negative or Neutral:
#
# Sentence: I love this AI course.
# The English Speaking course also does help you practice thinking well into this language class at very speed". Neutrian score. My friend found it entertaining reading how students practice self analysis techniques...!!... Very enjoyable class for good understanding, also fun absorbing text and engaging teacher so...+ Good amount

# %%
few_shot_prompt = """
Classify sentiment:

Sentence: I hate traffic.
Sentiment: Negative

Sentence: This movie is amazing.
Sentiment: Positive

Sentence: The food was average.
Sentiment: Neutral

Sentence: I really like this laptop.
Sentiment:
"""

print("Few Shot Result:")
print(ask_model(few_shot_prompt))
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Few Shot Result:
#
# Classify sentiment:
#
# Sentence: I hate traffic.
# Sentiment: Negative
#
# Sentence: This movie is amazing.
# Sentiment: Positive
#
# Sentence: The food was average.
# Sentiment: Neutral
#
# Sentence: I really like this laptop.
# Sentiment:

# %%
interview_prompt = """
You are a career counselor.

Ask 3 questions to understand student's interest, skills and goals.
Then suggest 2 career options.
"""

print("Interview Approach:")
print(ask_model(interview_prompt))
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Interview Approach:
#
# You are a career counselor.
#
# Ask 3 questions to understand student's interest, skills and goals.
# Then suggest 2 career options.
# ...

# %%
cot_prompt = """
Solve step by step:

A pen costs 20 rupees.
Shop gives 10% discount.
What is final price?
"""

print("CoT Result:")
print(ask_model(cot_prompt))
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# CoT Result:
#
# Solve step by step:
#
# A pen costs 20 rupees.
# Shop gives 10% discount.
# What is final price?
# ...

# %%
tot_prompt = """
Problem: Increase sales of a new food delivery app.

Step 1: Suggest 3 strategies.
Step 2: Give pros and cons of each.
Step 3: Select best strategy and explain why.
"""

print("ToT Result:")
print(ask_model(tot_prompt))
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ToT Result:
#
# Problem: Increase sales of a new food delivery app.
#
# Step 1: Suggest 3 strategies.
# Step 2: Give pros and cons of each.
# Step 3: Select best strategy and explain why.
# ing anyone rushing, fill orders (like they'delighted x5) The better technology at cost

# %%
print("""
Comparison:

Zero Shot:
- No examples
- Fast
- Less context understanding

Few Shot:
- Uses examples
- Better accuracy

Interview Approach:
- Personalized outputs

CoT:
- Good reasoning clarity

ToT:
- Best for complex decision making
""")
# Out:
# Comparison:
#
# Zero Shot:
# - No examples
# - Fast
# - Less context understanding
#
# Few Shot:
# - Uses examples
# - Better accuracy
#
# Interview Approach:
# - Personalized outputs
#
# CoT:
# - Good reasoning clarity
#
# ToT:
# - Best for complex decision making
