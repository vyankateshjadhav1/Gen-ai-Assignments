# %%
# !pip install langchain
# !pip install Cohere
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.0/319.0 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 85.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import os

#os.environ["OPENAI_API_KEY"] = "Your Key"
os.environ["COHERE_API_KEY"] = "YnAJiEwrvdSt1JqgJTb5eNKsbPUGdUozaKA8S9Fi"

# %%
# !pip install -U langchain-cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

llm = ChatCohere()
messages = [
    HumanMessage(
        content="What should I include in my diet to stay energetic and make a productive day?"
    )
]
result = llm.invoke(messages)
print(result.content)
# Out:
# Staying energetic and productive throughout the day starts with a balanced diet that provides sustained energy, mental clarity, and essential nutrients. Here’s what to include in your diet:
#
# ### **1. Complex Carbohydrates**
# - **Why:** Provide steady, long-lasting energy.
# - **Sources:** Whole grains (oats, quinoa, brown rice), sweet potatoes, legumes (lentils, chickpeas), and whole-grain bread.
#
# ### **2. Lean Proteins**
# - **Why:** Support muscle repair, stabilize blood sugar, and promote satiety.
# - **Sources:** Chicken, turkey, fish (salmon, tuna), eggs, tofu, tempeh, Greek yogurt, and beans.
#
# ### **3. Healthy Fats**
# - **Why:** Provide sustained energy and support brain function.
# - **Sources:** Avocado, nuts (almonds, walnuts), seeds (chia, flax, pumpkin), olive oil, and fatty fish (salmon, mackerel).
#
# ### **4. Fruits and Vegetables**
# - **Why:** Rich in vitamins, minerals, antioxidants, and fiber for overall health and energy.
# ...

# %%
prompt = """
What is sentiment of this review. Give one word answer p or n.
The food was tasty and the service was good. I had good experience of the hotel.
"""
result=llm.invoke(prompt)
print(result)
# Out:
# content='p' additional_kwargs={'id': '34f79c0b-e8f5-4d11-bf89-65caa35dca57', 'finish_reason': 'COMPLETE', 'content': 'p', 'token_count': {'input_tokens': 531.0, 'output_tokens': 4.0}} response_metadata={'id': '34f79c0b-e8f5-4d11-bf89-65caa35dca57', 'finish_reason': 'COMPLETE', 'content': 'p', 'token_count': {'input_tokens': 531.0, 'output_tokens': 4.0}} id='lc_run--019c1d37-9f15-7a93-9846-de0b86fc2dad-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 531, 'output_tokens': 4, 'total_tokens': 535}

# %%
prompt = """
What is sentiment of this review. Give one word answer p or n.
The food was bad and the service was bad. I had bad experience of the hotel.
"""
result=llm.invoke(prompt)
print(result)
# Out:
# content='n' additional_kwargs={'id': '883efc03-aaf2-47f6-b591-abb5ad31185c', 'finish_reason': 'COMPLETE', 'content': 'n', 'token_count': {'input_tokens': 531.0, 'output_tokens': 4.0}} response_metadata={'id': '883efc03-aaf2-47f6-b591-abb5ad31185c', 'finish_reason': 'COMPLETE', 'content': 'n', 'token_count': {'input_tokens': 531.0, 'output_tokens': 4.0}} id='lc_run--019c1d37-f265-7911-9002-f04547f17688-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 531, 'output_tokens': 4, 'total_tokens': 535}
